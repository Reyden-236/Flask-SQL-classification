# %%
import pandas as pd
import numpy as np
import pickle as pkl

# %%
df = pd.read_csv(r"C:\Users\Raashid\jupyter notebook\Sem 4\CIA 2\mobile price\train.csv")

# %%
df.drop(columns=['blue','fc','m_dep','pc','sc_h','sc_w','talk_time'],inplace = True)

# %%
df
# Out:
#       battery_power  clock_speed  dual_sim  four_g  int_memory  mobile_wt  \
# 0               842          2.2         0       0           7        188
# 1              1021          0.5         1       1          53        136
# 2               563          0.5         1       1          41        145
# 3               615          2.5         0       0          10        131
# 4              1821          1.2         0       1          44        141
# ...             ...          ...       ...     ...         ...        ...
# 1995            794          0.5         1       1           2        106
# 1996           1965          2.6         1       0          39        187
# 1997           1911          0.9         1       1          36        108
# 1998           1512          0.9         0       1          46        145
# 1999            510          2.0         1       1          45        168
#
#       n_cores  px_height  px_width   ram  three_g  touch_screen  wifi  \
# 0           2         20       756  2549        0             0     1
# 1           3        905      1988  2631        1             1     0
# 2           5       1263      1716  2603        1             1     0
# 3           6       1216      1786  2769        1             0     0
# 4           2       1208      1212  1411        1             1     0
# ...       ...        ...       ...   ...      ...           ...   ...
# 1995        6       1222      1890   668        1             1     0
# 1996        4        915      1965  2032        1             1     1
# 1997        8        868      1632  3057        1             1     0
# 1998        5        336       670   869        1             1     1
# 1999        6        483       754  3919        1             1     1
#
#       price_range
# 0               1
# 1               2
# 2               2
# 3               2
# 4               1
# ...           ...
# 1995            0
# 1996            2
# 1997            3
# 1998            0
# 1999            3
#
# [2000 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   clock_speed    2000 non-null   float64
#  2   dual_sim       2000 non-null   int64
#  3   four_g         2000 non-null   int64
#  4   int_memory     2000 non-null   int64
#  5   mobile_wt      2000 non-null   int64
#  6   n_cores        2000 non-null   int64
#  7   px_height      2000 non-null   int64
#  8   px_width       2000 non-null   int64
#  9   ram            2000 non-null   int64
#  10  three_g        2000 non-null   int64
#  11  touch_screen   2000 non-null   int64
#  12  wifi           2000 non-null   int64
#  13  price_range    2000 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 218.9 KB

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pkl.dump(log,open('reg.pkl','wb'))
